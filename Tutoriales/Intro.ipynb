# %% [markdown]
# El primer TP va a ser hacer un simulador de un procesador en C.
#
# Por el lado de Arquitectura de computadoras veremos:
#
# - Arquitectura de computadoras tiene que ver con como el hardware ejecuta instrucciones. Como funciona un cpu si sacas el software.
#
# - Cual es el codigo de un procesaodr (Assembly)
#
# - Como pasamos de C a Assembly
#
#
# Por el lado de Sistemas Operativos veremos:
#
# - System Calls
#
# - Que es un proceso, como se crean varios, como se comunican.
#
# - Que son Threads, y como programar con multithreading
#
# - Discos, RAIDs, particiones, hotswap
#
# - File Systems, como se guardan archivos en disco.

# %% [markdown]
# Numeros en base binaria
#
# Numeros en base hexadecimal
#
# Numeros en base decimal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tipos de Enteros:
#
# ![image.png](attachment:image.png)
#
# Unsigned representacion de 4 bites
#
# ![image-2.png](attachment:image-2.png)
